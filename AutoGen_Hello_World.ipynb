# %% [markdown]
# <a href="https://colab.research.google.com/github/aknip/Autogen-AutoGPT/blob/main/AutoGen_Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AutoGen Hello World
#
# How to:
#
# - lorem
# - ipsum
#
# Source: https://github.com/microsoft/autogen/blob/main/notebook/agentchat_web_info.ipynb

# %%
import json
import os
from getpass import getpass
import psutil
IN_NOTEBOOK = any(["jupyter-notebook" in i for i in psutil.Process().parent().cmdline()])
if IN_NOTEBOOK:
  CREDS = json.loads(getpass("Secrets (JSON string): "))
  os.environ['CREDS'] = json.dumps(CREDS)
  CREDS = json.loads(os.getenv('CREDS'))

# %%
# !pip install pyautogen~=0.1.0 docker

# %% [markdown]
# ## Set your API Endpoint
#
# The [`config_list_from_json`](https://microsoft.github.io/autogen/docs/reference/oai/openai_utils#config_list_from_json) function loads a list of configurations from an environment variable or a json file.

# %%
import autogen

config_list = [{'model': 'gpt-4', 'api_key': CREDS['OpenAI']['v1']['credential']}]

llm_config={
    "request_timeout": 600,
    "seed": 42,
    "config_list": config_list,
    "temperature": 0,
}
#print(config_list)

# %% [markdown]
# ## Construct Agents
#
# We construct the assistant agent and the user proxy agent. We specify `human_input_mode` as "TERMINATE" in the user proxy agent, which will ask for human feedback when it receives a "TERMINATE" signal from the assistant agent.

# %%
# create an AssistantAgent instance named "assistant"
assistant = autogen.AssistantAgent(
    name="assistant",
    llm_config=llm_config,
)
# create a UserProxyAgent instance named "user_proxy"
user_proxy = autogen.UserProxyAgent(
    name="user_proxy",
    human_input_mode="TERMINATE",
    max_consecutive_auto_reply=10,
    is_termination_msg=lambda x: x.get("content", "").rstrip().endswith("TERMINATE"),
    code_execution_config={"work_dir": "web"},
    llm_config=llm_config,
    system_message="""Reply TERMINATE if the task has been solved at full satisfaction.
Otherwise, reply CONTINUE, or the reason why the task is not solved yet."""
)

# %% [markdown]
# ## Example Task: Paper Talk from URL
#
# We invoke the `initiate_chat()` method of the user proxy agent to start the conversation. When you run the cell below, you will be prompted to provide feedback after the assistant agent sends a "TERMINATE" signal in the end of the message. If you don't provide any feedback (by pressing Enter directly), the conversation will finish. Before the "TERMINATE" signal, the user proxy agent will try to execute the code suggested by the assistant agent on behalf of the user.

# %%
# the assistant receives a message from the user, which contains the task description
user_proxy.initiate_chat(
    assistant,
    message="""
Who should read this paper: https://arxiv.org/abs/2308.08155
""",
)
# Out:
# user_proxy (to assistant):
#
#
# Who should read this paper: https://arxiv.org/abs/2308.08155
#
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# To determine who should read the paper, we first need to understand the content and context of the paper. We can do this by fetching the abstract of the paper from the provided URL and analyzing it.
#
# Here is a Python script that uses the BeautifulSoup library to scrape the abstract from the webpage.
#
# ```python
# # filename: fetch_abstract.py
#
# import requests
# from bs4 import BeautifulSoup
#
# def fetch_abstract(url):
#     response = requests.get(url)
#     soup = BeautifulSoup(response.text, 'html.parser')
#     abstract = soup.find('blockquote', attrs={'class': 'abstract mathjax'}).text
#     return abstract
#
# url = "https://arxiv.org/abs/2308.08155"
# print(fetch_abstract(url))
# ```
#
# Please run this script to fetch the abstract of the paper. After that, I will analyze the abstract and suggest who should read the paper.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
#
# >>>>>>>> EXECUTING CODE BLOCK 0 (inferred language is python)...
# user_proxy (to assistant):
#
# exitcode: 0 (execution succeeded)
# Code output:
#
# Abstract:AutoGen is an open-source framework that allows developers to build LLM applications via multiple agents that can converse with each other to accomplish tasks. AutoGen agents are customizable, conversable, and can operate in various modes that employ combinations of LLMs, human inputs, and tools. Using AutoGen, developers can also flexibly define agent interaction behaviors. Both natural language and computer code can be used to program flexible conversation patterns for different applications. AutoGen serves as a generic infrastructure to build diverse applications of various complexities and LLM capacities. Empirical studies demonstrate the effectiveness of the framework in many example applications, with domains ranging from mathematics, coding, question answering, operations research, online decision-making, entertainment, etc.
#
#
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# Based on the abstract, the paper is about AutoGen, an open-source framework that allows developers to build applications using multiple agents that can converse with each other to accomplish tasks. The framework is customizable and can operate in various modes that employ combinations of language models, human inputs, and tools. It can be used to build diverse applications of various complexities and capacities.
#
# Given this, the paper should be of interest to:
#
# 1. **Software Developers and Engineers**: Especially those interested in building applications using language models and multi-agent systems. They can learn about the AutoGen framework and how it can be used to build diverse applications.
#
# 2. **Researchers in Artificial Intelligence and Machine Learning**: They can gain insights into the design and implementation of the AutoGen framework, and how it employs language models and multi-agent systems to accomplish tasks.
#
# 3. **Data Scientists**: They can understand how language models and multi-agent systems can be used in practical applications.
#
# 4. **Students studying Computer Science, Artificial Intelligence, or related fields**: They can learn about the practical applications of language models and multi-agent systems.
#
# 5. **Professionals in fields like Mathematics, Operations Research, Online Decision-Making, Entertainment, etc.**: As the framework has been demonstrated to be effective in these domains, professionals in these fields might find the paper useful to understand how such a framework can be applied in their respective fields.
#
# TERMINATE
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e991304a1cb6> in <cell line: 2>()
#       1 # the assistant receives a message from the user, which contains the task description
# ----> 2 user_proxy.initiate_chat(
#       3     assistant,
#       4     message="""
#       5 Who should read this paper: https://arxiv.org/abs/2308.08155
#
# /usr/local/lib/python3.10/dist-packages/autogen/agentchat/conversable_agent.py in initiate_chat(self, recipient, clear_history, silent, **context)
#     529         """
#     530         self._prepare_chat(recipient, clear_history)
# --> 531         self.send(self.generate_init_message(**context), recipient, silent=silent)
#     532
#     533     async def a_initiate_chat(
#
# /usr/local/lib/python3.10/dist-packages/autogen/agentchat/conversable_agent.py in send(self, message, recipient, request_reply, silent)
#     332         valid = self._append_oai_message(message, "assistant", recipient)
#     333         if valid:
# --> 334             recipient.receive(message, self, request_reply, silent)
#     335         else:
#     336             raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/autogen/agentchat/conversable_agent.py in receive(self, message, sender, request_reply, silent)
#     462         reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     463         if reply is not None:
# --> 464             self.send(reply, sender, silent=silent)
#     465
#     466     async def a_receive(
#
# /usr/local/lib/python3.10/dist-packages/autogen/agentchat/conversable_agent.py in send(self, message, recipient, request_reply, silent)
#     332         valid = self._append_oai_message(message, "assistant", recipient)
#     333         if valid:
# --> 334             recipient.receive(message, self, request_reply, silent)
#     335         else:
#     336             raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/autogen/agentchat/conversable_agent.py in receive(self, message, sender, request_reply, silent)
#     462         reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     463         if reply is not None:
# --> 464             self.send(reply, sender, silent=silent)
#     465
#     466     async def a_receive(
#
# /usr/local/lib/python3.10/dist-packages/autogen/agentchat/conversable_agent.py in send(self, message, recipient, request_reply, silent)
#     332         valid = self._append_oai_message(message, "assistant", recipient)
#     333         if valid:
# --> 334             recipient.receive(message, self, request_reply, silent)
#     335         else:
#     336             raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/autogen/agentchat/conversable_agent.py in receive(self, message, sender, request_reply, silent)
#     462         reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     463         if reply is not None:
# --> 464             self.send(reply, sender, silent=silent)
#     465
#     466     async def a_receive(
#
# /usr/local/lib/python3.10/dist-packages/autogen/agentchat/conversable_agent.py in send(self, message, recipient, request_reply, silent)
#     332         valid = self._append_oai_message(message, "assistant", recipient)
#     333         if valid:
# --> 334             recipient.receive(message, self, request_reply, silent)
#     335         else:
#     336             raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/autogen/agentchat/conversable_agent.py in receive(self, message, sender, request_reply, silent)
#     460         if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     461             return
# --> 462         reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     463         if reply is not None:
#     464             self.send(reply, sender, silent=silent)
#
# /usr/local/lib/python3.10/dist-packages/autogen/agentchat/conversable_agent.py in generate_reply(self, messages, sender, exclude)
#     777                 continue
#     778             if self._match_trigger(reply_func_tuple["trigger"], sender):
# --> 779                 final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#     780                 if final:
#     781                     return reply
#
# /usr/local/lib/python3.10/dist-packages/autogen/agentchat/conversable_agent.py in check_termination_and_human_reply(self, messages, sender, config)
#     701                 else:
#     702                     # self.human_input_mode == "TERMINATE":
# --> 703                     reply = self.get_human_input(
#     704                         f"Please give feedback to {sender.name}. Press enter or type 'exit' to stop the conversation: "
#     705                     )
#
# /usr/local/lib/python3.10/dist-packages/autogen/agentchat/conversable_agent.py in get_human_input(self, prompt)
#     864             str: human input.
#     865         """
# --> 866         reply = input(prompt)
#     867         return reply
#     868
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## Example Task: Chat about Stock Market

# %%
user_proxy.initiate_chat(
    assistant,
    message="""Show me the YTD gain of 10 largest technology companies as of today.""",
)
# Out:
# user_proxy (to assistant):
#
# Show me the YTD gain of 10 largest technology companies as of today.
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# To get the YTD gain of the 10 largest technology companies, we need to do the following:
#
# 1. Identify the 10 largest technology companies. We can use the list of the largest technology companies by market capitalization. This list can change frequently, so we need to get the latest data. We can use web scraping to get this data from a reliable source.
#
# 2. Get the YTD gain for each of these companies. We can use a financial data API to get this data. Yahoo Finance is a popular source for this kind of data.
#
# Here is a Python script that uses the BeautifulSoup library for web scraping and the yfinance library to get data from Yahoo Finance. This script will print the 10 largest technology companies and their YTD gains.
#
# ```python
# # filename: ytd_gain.py
#
# import requests
# from bs4 import BeautifulSoup
# import yfinance as yf
# import pandas as pd
#
# # Get the list of largest tech companies by market cap
# url = "https://companiesmarketcap.com/technology/largest-technology-companies-by-market-cap/"
# response = requests.get(url)
# soup = BeautifulSoup(response.text, 'html.parser')
#
# # Find the table with the data
# table = soup.find('table')
#
# # Get the ticker symbols of the 10 largest companies
# tickers = []
# for row in table.find_all('tr')[1:11]:  # Skip the header row
#     ticker = row.find_all('td')[1].text
#     tickers.append(ticker)
#
# # Get the YTD gain for each company
# ytd_gains = {}
# for ticker in tickers:
#     ticker_data = yf.Ticker(ticker)
#     hist = ticker_data.history(period="ytd")
#     start_price = hist.iloc[0]['Close']
#     end_price = hist.iloc[-1]['Close']
#     ytd_gain = (end_price - start_price) / start_price * 100
#     ytd_gains[ticker] = ytd_gain
#
# # Print the results
# for ticker, ytd_gain in ytd_gains.items():
#     print(f"{ticker}: {ytd_gain:.2f}%")
# ```
#
# To run this script, save it to a file named `ytd_gain.py`, then run it with the command `python ytd_gain.py`.
#
# Please note that this script requires the BeautifulSoup, requests, yfinance, and pandas libraries. If you don't have these libraries installed, you can install them with the command `pip install beautifulsoup4 requests yfinance pandas`.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
#
# >>>>>>>> EXECUTING CODE BLOCK 0 (inferred language is python)...
# user_proxy (to assistant):
#
# exitcode: 1 (execution failed)
# Code output:
# Traceback (most recent call last):
#   File "ytd_gain.py", line 18, in <module>
#     for row in table.find_all('tr')[1:11]:  # Skip the header row
# AttributeError: 'NoneType' object has no attribute 'find_all'
#
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# I apologize for the error. It seems that the script failed to find the table in the webpage. This could be due to changes in the webpage structure or because the page uses JavaScript to load the table, which BeautifulSoup can't handle.
#
# Let's try a different approach. We'll use the yfinance library to get the data for the 10 largest technology companies. These are currently: Apple (AAPL), Microsoft (MSFT), Alphabet (GOOGL), Amazon (AMZN), Facebook (FB), Tesla (TSLA), Nvidia (NVDA), Paypal (PYPL), Adobe (ADBE), and Netflix (NFLX).
#
# Here's the updated Python script:
#
# ```python
# # filename: ytd_gain.py
#
# import yfinance as yf
#
# # List of the 10 largest tech companies by market cap
# tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'FB', 'TSLA', 'NVDA', 'PYPL', 'ADBE', 'NFLX']
#
# # Get the YTD gain for each company
# ytd_gains = {}
# for ticker in tickers:
#     ticker_data = yf.Ticker(ticker)
#     hist = ticker_data.history(period="ytd")
#     start_price = hist.iloc[0]['Close']
#     end_price = hist.iloc[-1]['Close']
#     ytd_gain = (end_price - start_price) / start_price * 100
#     ytd_gains[ticker] = ytd_gain
#
# # Print the results
# for ticker, ytd_gain in ytd_gains.items():
#     print(f"{ticker}: {ytd_gain:.2f}%")
# ```
#
# To run this script, save it to a file named `ytd_gain.py`, then run it with the command `python ytd_gain.py`.
#
# Please note that this script requires the yfinance library. If you don't have this library installed, you can install it with the command `pip install yfinance`.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
#
# >>>>>>>> EXECUTING CODE BLOCK 0 (inferred language is python)...
# user_proxy (to assistant):
#
# exitcode: 1 (execution failed)
# Code output:
# FB: No data found, symbol may be delisted
# Traceback (most recent call last):
#   File "ytd_gain.py", line 13, in <module>
#     start_price = hist.iloc[0]['Close']
#   File "/home/vscode/.local/lib/python3.9/site-packages/pandas/core/indexing.py", line 931, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "/home/vscode/.local/lib/python3.9/site-packages/pandas/core/indexing.py", line 1566, in _getitem_axis
#     self._validate_integer(key, axis)
#   File "/home/vscode/.local/lib/python3.9/site-packages/pandas/core/indexing.py", line 1500, in _validate_integer
#     raise IndexError("single positional indexer is out-of-bounds")
# IndexError: single positional indexer is out-of-bounds
#
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# I apologize for the error. It seems that the script failed to get the data for Facebook (FB). This could be due to a temporary issue with the Yahoo Finance API.
#
# Let's modify the script to handle this situation. We'll add a try-except block to skip any companies for which we can't get data.
#
# Here's the updated Python script:
#
# ```python
# # filename: ytd_gain.py
#
# import yfinance as yf
#
# # List of the 10 largest tech companies by market cap
# tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'FB', 'TSLA', 'NVDA', 'PYPL', 'ADBE', 'NFLX']
#
# # Get the YTD gain for each company
# ytd_gains = {}
# for ticker in tickers:
#     try:
#         ticker_data = yf.Ticker(ticker)
#         hist = ticker_data.history(period="ytd")
#         start_price = hist.iloc[0]['Close']
#         end_price = hist.iloc[-1]['Close']
#         ytd_gain = (end_price - start_price) / start_price * 100
#         ytd_gains[ticker] = ytd_gain
#     except IndexError:
#         print(f"Could not get data for {ticker}")
#
# # Print the results
# for ticker, ytd_gain in ytd_gains.items():
#     print(f"{ticker}: {ytd_gain:.2f}%")
# ```
#
# To run this script, save it to a file named `ytd_gain.py`, then run it with the command `python ytd_gain.py`.
#
# Please note that this script requires the yfinance library. If you don't have this library installed, you can install it with the command `pip install yfinance`.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
#
# >>>>>>>> EXECUTING CODE BLOCK 0 (inferred language is python)...
# user_proxy (to assistant):
#
# exitcode: 0 (execution succeeded)
# Code output:
# Could not get data for FB
# AAPL: 46.41%
# MSFT: 37.63%
# GOOGL: 51.13%
# AMZN: 56.22%
# TSLA: 131.46%
# NVDA: 237.68%
# PYPL: -16.49%
# ADBE: 59.79%
# NFLX: 43.41%
#
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# The script has successfully fetched the Year-to-Date (YTD) gain for the largest technology companies, except for Facebook (FB). The YTD gains are as follows:
#
# - Apple (AAPL): 46.41%
# - Microsoft (MSFT): 37.63%
# - Alphabet (GOOGL): 51.13%
# - Amazon (AMZN): 56.22%
# - Tesla (TSLA): 131.46%
# - Nvidia (NVDA): 237.68%
# - Paypal (PYPL): -16.49%
# - Adobe (ADBE): 59.79%
# - Netflix (NFLX): 43.41%
#
# Unfortunately, the script could not fetch the data for Facebook (FB). This could be due to a temporary issue with the Yahoo Finance API or the ticker symbol might have changed.
#
# Please note that these values are subject to change as the stock market fluctuates.
#
# TERMINATE
#
# --------------------------------------------------------------------------------
# user_proxy (to assistant):
#
# FB -> META
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# Thank you for the update. Facebook Inc. has indeed rebranded to Meta Platforms Inc. and its ticker symbol has changed from FB to META on the NASDAQ stock exchange.
#
# Let's update the script to reflect this change:
#
# ```python
# # filename: ytd_gain.py
#
# import yfinance as yf
#
# # List of the 10 largest tech companies by market cap
# # Updated Facebook (FB) to Meta Platforms (META)
# tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'META', 'TSLA', 'NVDA', 'PYPL', 'ADBE', 'NFLX']
#
# # Get the YTD gain for each company
# ytd_gains = {}
# for ticker in tickers:
#     try:
#         ticker_data = yf.Ticker(ticker)
#         hist = ticker_data.history(period="ytd")
#         start_price = hist.iloc[0]['Close']
#         end_price = hist.iloc[-1]['Close']
#         ytd_gain = (end_price - start_price) / start_price * 100
#         ytd_gains[ticker] = ytd_gain
#     except IndexError:
#         print(f"Could not get data for {ticker}")
#
# # Print the results
# for ticker, ytd_gain in ytd_gains.items():
#     print(f"{ticker}: {ytd_gain:.2f}%")
# ```
#
# To run this script, save it to a file named `ytd_gain.py`, then run it with the command `python ytd_gain.py`.
#
# Please note that this script requires the yfinance library. If you don't have this library installed, you can install it with the command `pip install yfinance`.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
#
# >>>>>>>> EXECUTING CODE BLOCK 0 (inferred language is python)...
# user_proxy (to assistant):
#
# exitcode: 0 (execution succeeded)
# Code output:
# AAPL: 46.34%
# MSFT: 37.55%
# GOOGL: 51.08%
# AMZN: 56.17%
# META: 133.67%
# TSLA: 131.02%
# NVDA: 237.38%
# PYPL: -16.55%
# ADBE: 59.71%
# NFLX: 43.44%
#
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# The script has successfully fetched the Year-to-Date (YTD) gain for the largest technology companies, including Meta Platforms (formerly Facebook). The YTD gains are as follows:
#
# - Apple (AAPL): 46.34%
# - Microsoft (MSFT): 37.55%
# - Alphabet (GOOGL): 51.08%
# - Amazon (AMZN): 56.17%
# - Meta Platforms (META): 133.67%
# - Tesla (TSLA): 131.02%
# - Nvidia (NVDA): 237.38%
# - Paypal (PYPL): -16.55%
# - Adobe (ADBE): 59.71%
# - Netflix (NFLX): 43.44%
#
# Please note that these values are subject to change as the stock market fluctuates.
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> NO HUMAN INPUT RECEIVED.
